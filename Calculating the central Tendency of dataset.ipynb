# %%
import pandas as pd
dataset=pd.read_csv("AirPassengers.csv")
dataset.head()
# Out:
#      Month  #Passengers
# 0  1949-01          112
# 1  1949-02          118
# 2  1949-03          132
# 3  1949-04          129
# 4  1949-05          121

# %%
sample_data_set=dataset["#Passengers"]

# %%
df=pd.DataFrame(sample_data_set)

# %%
df.info
# Out:
# <bound method DataFrame.info of      #Passengers
# 0            112
# 1            118
# 2            132
# 3            129
# 4            121
# ..           ...
# 139          606
# 140          508
# 141          461
# 142          390
# 143          432
#
# [144 rows x 1 columns]>

# %%
df.size
# Out:
# 144

# %%
df.plot()
# Out:
# <AxesSubplot:>

# %%
sample_data_set.plot()
# Out:
# <AxesSubplot:>

# %%
# calculating central tendency of df now

# %%
#mean
df.mean()
# Out:
# #Passengers    280.298611
# dtype: float64

# %%
df.median()
# Out:
# #Passengers    265.5
# dtype: float64

# %%
df.mode()
# Out:
#    #Passengers
# 0          229
